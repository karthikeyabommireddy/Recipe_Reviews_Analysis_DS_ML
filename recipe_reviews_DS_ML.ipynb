# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/home/eeswar_obulasetty/Downloads/project_work/Recipe Reviews and User Feedback Dataset.csv')

# %%
df
# Out:
#        Unnamed: 0  recipe_number  recipe_code                    recipe_name  \
# 0               0              1        14299             Creamy White Chili
# 1               1              1        14299             Creamy White Chili
# 2               2              1        14299             Creamy White Chili
# 3               3              1        14299             Creamy White Chili
# 4               4              1        14299             Creamy White Chili
# ...           ...            ...          ...                            ...
# 18177         114            100        82745  Mamaw Emily’s Strawberry Cake
# 18178         115            100        82745  Mamaw Emily’s Strawberry Cake
# 18179         116            100        82745  Mamaw Emily’s Strawberry Cake
# 18180         117            100        82745  Mamaw Emily’s Strawberry Cake
# 18181         118            100        82745  Mamaw Emily’s Strawberry Cake
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'recipe_number', 'recipe_code', 'recipe_name',
#        'comment_id', 'user_id', 'user_name', 'user_reputation', 'created_at',
#        'reply_count', 'thumbs_up', 'thumbs_down', 'stars', 'best_score',
#        'text'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Unnamed: 0         0
# recipe_number      0
# recipe_code        0
# recipe_name        0
# comment_id         0
# user_id            0
# user_name          0
# user_reputation    0
# created_at         0
# reply_count        0
# thumbs_up          0
# thumbs_down        0
# stars              0
# best_score         0
# text               2
# dtype: int64

# %%
df.dropna(subset=['text'],inplace=True)

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#        Unnamed: 0  recipe_number  recipe_code                    recipe_name  \
# 0               0              1        14299             Creamy White Chili
# 1               1              1        14299             Creamy White Chili
# 2               2              1        14299             Creamy White Chili
# 3               3              1        14299             Creamy White Chili
# 4               4              1        14299             Creamy White Chili
# ...           ...            ...          ...                            ...
# 18175         114            100        82745  Mamaw Emily’s Strawberry Cake
# 18176         115            100        82745  Mamaw Emily’s Strawberry Cake
# 18177         116            100        82745  Mamaw Emily’s Strawberry Cake
# 18178         117            100        82745  Mamaw Emily’s Strawberry Cake
# 18179         118            100        82745  Mamaw Emily’s Strawberry Cake
#
# ...

# %%
df.shape
# Out:
# (18180, 15)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'recipe_number', 'recipe_code', 'recipe_name',
#        'comment_id', 'user_id', 'user_name', 'user_reputation', 'created_at',
#        'reply_count', 'thumbs_up', 'thumbs_down', 'stars', 'best_score',
#        'text'],
#       dtype='object')

# %%
df.drop(columns=['Unnamed: 0', 'recipe_number', 'recipe_code','comment_id','created_at'],inplace=True)

# %%
df
# Out:
#                          recipe_name                        user_id  \
# 0                 Creamy White Chili                 u_9iFLIhMa8QaG
# 1                 Creamy White Chili                 u_Lu6p25tmE77j
# 2                 Creamy White Chili                 u_s0LwgpZ8Jsqq
# 3                 Creamy White Chili                 u_fqrybAdYjgjG
# 4                 Creamy White Chili                 u_XXWKwVhKZD69
# ...                              ...                            ...
# 18175  Mamaw Emily’s Strawberry Cake  u_1oKblS4ULpTAACUTILo0QlO5mrN
# 18176  Mamaw Emily’s Strawberry Cake  u_1oKY7CKLaFQpI3cBCVaxHXAEGbt
# 18177  Mamaw Emily’s Strawberry Cake  u_1oKXBAuHbMDi9nnriVAbJoPqpeQ
# 18178  Mamaw Emily’s Strawberry Cake  u_1oKVbnueXfnlmYWuYH8xJ0mFxNQ
# 18179  Mamaw Emily’s Strawberry Cake  u_1oKW6W12cOLxiMzjA7j8nTqwFWG
#
#         user_name  user_reputation  reply_count  thumbs_up  thumbs_down  \
# 0         Jeri326                1            0          0            0
# ...

# %%
from category_encoders import TargetEncoder

# %%
encoder=TargetEncoder()

# %%
X=df['recipe_name']

# %%
y=df['stars']

# %%
X_encoded=encoder.fit_transform(X,y)

# %%
df['recipe_name']=X_encoded

# %%
df
# Out:
#        recipe_name                        user_id   user_name  \
# 0         4.452599                 u_9iFLIhMa8QaG     Jeri326
# 1         4.452599                 u_Lu6p25tmE77j     Mark467
# 2         4.452599                 u_s0LwgpZ8Jsqq  Barbara566
# 3         4.452599                 u_fqrybAdYjgjG  jeansch123
# 4         4.452599                 u_XXWKwVhKZD69    camper77
# ...            ...                            ...         ...
# 18175     4.369744  u_1oKblS4ULpTAACUTILo0QlO5mrN  WhittierCA
# 18176     4.369744  u_1oKY7CKLaFQpI3cBCVaxHXAEGbt   susieswan
# 18177     4.369744  u_1oKXBAuHbMDi9nnriVAbJoPqpeQ       blajr
# 18178     4.369744  u_1oKVbnueXfnlmYWuYH8xJ0mFxNQ     cafritz
# 18179     4.369744  u_1oKW6W12cOLxiMzjA7j8nTqwFWG    nopalito
#
#        user_reputation  reply_count  thumbs_up  thumbs_down  stars  \
# 0                    1            0          0            0      5
# 1                   50            0          7            0      5
# ...

# %%
import nltk

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('punkt_tab')
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/eeswar_obulasetty/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/eeswar_obulasetty/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/eeswar_obulasetty/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# %%
import re
import string

# %%
def preprocess(text):
    if not isinstance(text, str):
        return [] 
    text = text.lower()
    text = re.sub(r'\d+', '', text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    tokens = word_tokenize(text)
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    return tokens
df['text'] = df['text'].apply(preprocess)

# %%
df
# Out:
#        recipe_name                        user_id   user_name  \
# 0         4.452599                 u_9iFLIhMa8QaG     Jeri326
# 1         4.452599                 u_Lu6p25tmE77j     Mark467
# 2         4.452599                 u_s0LwgpZ8Jsqq  Barbara566
# 3         4.452599                 u_fqrybAdYjgjG  jeansch123
# 4         4.452599                 u_XXWKwVhKZD69    camper77
# ...            ...                            ...         ...
# 18175     4.369744  u_1oKblS4ULpTAACUTILo0QlO5mrN  WhittierCA
# 18176     4.369744  u_1oKY7CKLaFQpI3cBCVaxHXAEGbt   susieswan
# 18177     4.369744  u_1oKXBAuHbMDi9nnriVAbJoPqpeQ       blajr
# 18178     4.369744  u_1oKVbnueXfnlmYWuYH8xJ0mFxNQ     cafritz
# 18179     4.369744  u_1oKW6W12cOLxiMzjA7j8nTqwFWG    nopalito
#
#        user_reputation  reply_count  thumbs_up  thumbs_down  stars  \
# 0                    1            0          0            0      5
# 1                   50            0          7            0      5
# ...

# %%
df.shape
# Out:
# (18180, 10)

# %%
from gensim.models import Word2Vec

# %%
sentences = df['text'].tolist()
w2v_model = Word2Vec(sentences,vector_size=100,window=5,min_count=1,workers=4,sg=1)

# %%
def review_vector(tokens, model, vector_size=100):
    vec = np.zeros(vector_size)
    count = 0
    for word in tokens:
        if word in model.wv:
            vec += model.wv[word]
            count += 1
    if count != 0:
        vec /= count
    return vec

# %%
df['review_vector'] = df['text'].apply(lambda x: review_vector(x, w2v_model))

# %%
df
# Out:
#        recipe_name                        user_id   user_name  \
# 0         4.452599                 u_9iFLIhMa8QaG     Jeri326
# 1         4.452599                 u_Lu6p25tmE77j     Mark467
# 2         4.452599                 u_s0LwgpZ8Jsqq  Barbara566
# 3         4.452599                 u_fqrybAdYjgjG  jeansch123
# 4         4.452599                 u_XXWKwVhKZD69    camper77
# ...            ...                            ...         ...
# 18175     4.369744  u_1oKblS4ULpTAACUTILo0QlO5mrN  WhittierCA
# 18176     4.369744  u_1oKY7CKLaFQpI3cBCVaxHXAEGbt   susieswan
# 18177     4.369744  u_1oKXBAuHbMDi9nnriVAbJoPqpeQ       blajr
# 18178     4.369744  u_1oKVbnueXfnlmYWuYH8xJ0mFxNQ     cafritz
# 18179     4.369744  u_1oKW6W12cOLxiMzjA7j8nTqwFWG    nopalito
#
#        user_reputation  reply_count  thumbs_up  thumbs_down  stars  \
# 0                    1            0          0            0      5
# 1                   50            0          7            0      5
# ...

# %%
df.columns
# Out:
# Index(['recipe_name', 'user_id', 'user_name', 'user_reputation', 'reply_count',
#        'thumbs_up', 'thumbs_down', 'stars', 'best_score', 'text',
#        'review_vector'],
#       dtype='object')

# %%
df['user_name'].nunique(),df['user_id'].nunique()
# Out:
# (13586, 13812)

# %%
X=df[['recipe_name','thumbs_up','thumbs_down','review_vector']]
y=df['stars']

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,stratify=y,random_state=42)

# %%
model=DecisionTreeClassifier(criterion='entropy',max_depth=24,min_samples_split=22,max_leaf_nodes=30)

# %%
X = np.vstack(df['review_vector'].values) 
y = df['stars']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y)

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=24, max_leaf_nodes=30,
#                        min_samples_split=22)

# %%
model.score(X_test,y_test)
# Out:
# 0.7588558855885589

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
ConfusionMatrixDisplay.from_estimator(model,X_test,y_test)
plt.show()

# %%
model1=LogisticRegression(max_iter=20000000,C=3)

# %%
model1.fit(X_train,y_train)
# Out:
# LogisticRegression(C=3, max_iter=20000000)

# %%
model1.score(X_test,y_test)
# Out:
# 0.7696369636963697

# %%
import matplotlib.pyplot as plt

# %%
ConfusionMatrixDisplay.from_estimator(model1,X_test,y_test)
plt.show()

# %%
def func(t):
    if t<4:
        return 0
    else:
        return 1
df['sentiment']=df['stars'].apply(func)

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# 1    15482
# 0     2698
# Name: count, dtype: int64

# %%
df['sentiment'].value_counts(normalize=True)
# Out:
# sentiment
# 1    0.851595
# 0    0.148405
# Name: proportion, dtype: float64

# %%
y=df['sentiment']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,stratify=y)

# %%
model3=LogisticRegression(max_iter=10000000,class_weight='balanced',C=4)

# %%
model3.fit(X_train,y_train)
# Out:
# LogisticRegression(C=4, class_weight='balanced', max_iter=10000000)

# %%
model3.score(X_test,y_test)
# Out:
# 0.7034103410341034

# %%
ConfusionMatrixDisplay.from_estimator(model3,X_test,y_test)
plt.show()

# %%
model4=LogisticRegression(max_iter=100000000)

# %%
model4.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=100000000)

# %%
model4.score(X_test,y_test)
# Out:
# 0.8622662266226623

# %%
ConfusionMatrixDisplay.from_estimator(model4,X_test,y_test)
plt.show()

# %%
df.columns
# Out:
# Index(['recipe_name', 'user_id', 'user_name', 'user_reputation', 'reply_count',
#        'thumbs_up', 'thumbs_down', 'stars', 'best_score', 'text',
#        'review_vector', 'sentiment'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18180 entries, 0 to 18179
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   recipe_name      18180 non-null  float64
#  1   user_id          18180 non-null  object
#  2   user_name        18180 non-null  object
#  3   user_reputation  18180 non-null  int64
#  4   reply_count      18180 non-null  int64
#  5   thumbs_up        18180 non-null  int64
#  6   thumbs_down      18180 non-null  int64
#  7   stars            18180 non-null  int64
#  8   best_score       18180 non-null  int64
#  9   text             18180 non-null  object
#  10  review_vector    18180 non-null  object
#  11  sentiment        18180 non-null  int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 1.7+ MB

# %%
model5=DecisionTreeClassifier(criterion='entropy',max_depth=6,max_leaf_nodes=20,class_weight='balanced')

# %%
model5.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#                        max_depth=6, max_leaf_nodes=20)

# %%
model5.score(X_test,y_test)
# Out:
# 0.7163916391639163

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=[13,8])
plot_tree(model5)
plt.show()

# %%
ConfusionMatrixDisplay.from_estimator(model5,X_test,y_test)
plt.show()

# %%
ConfusionMatrixDisplay.from_estimator(model3,X_test,y_test)
plt.show()

# %%
y_pred=model5.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.29      0.61      0.39       675
#            1       0.91      0.74      0.82      3870
#
#     accuracy                           0.72      4545
#    macro avg       0.60      0.67      0.60      4545
# weighted avg       0.82      0.72      0.75      4545

# %%
print(classification_report(y_test,model3.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.29      0.68      0.41       675
#            1       0.93      0.71      0.80      3870
#
#     accuracy                           0.70      4545
#    macro avg       0.61      0.69      0.60      4545
# weighted avg       0.83      0.70      0.74      4545

# %%
# Comparing both i feel choosing Decision Tree model is the best option to follow

# %%
df
# Out:
#        recipe_name                        user_id   user_name  \
# 0         4.452599                 u_9iFLIhMa8QaG     Jeri326
# 1         4.452599                 u_Lu6p25tmE77j     Mark467
# 2         4.452599                 u_s0LwgpZ8Jsqq  Barbara566
# 3         4.452599                 u_fqrybAdYjgjG  jeansch123
# 4         4.452599                 u_XXWKwVhKZD69    camper77
# ...            ...                            ...         ...
# 18175     4.369744  u_1oKblS4ULpTAACUTILo0QlO5mrN  WhittierCA
# 18176     4.369744  u_1oKY7CKLaFQpI3cBCVaxHXAEGbt   susieswan
# 18177     4.369744  u_1oKXBAuHbMDi9nnriVAbJoPqpeQ       blajr
# 18178     4.369744  u_1oKVbnueXfnlmYWuYH8xJ0mFxNQ     cafritz
# 18179     4.369744  u_1oKW6W12cOLxiMzjA7j8nTqwFWG    nopalito
#
#        user_reputation  reply_count  thumbs_up  thumbs_down  stars  \
# 0                    1            0          0            0      5
# 1                   50            0          7            0      5
# ...

# %%
X=df[['recipe_name','user_reputation','reply_count','thumbs_up','thumbs_down','stars']]

# %%
y=df['best_score']

# %%
from sklearn.linear_model import LinearRegression

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y)

# %%
model6=LinearRegression()

# %%
model6.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model6.score(X_test,y_test)
# Out:
# 0.45454870790504187

# %%
import statsmodels.api as sm

# %%
model7=sm.OLS(y,X).fit()

# %%
model7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             best_score   R-squared (uncentered):                   0.762
# Model:                            OLS   Adj. R-squared (uncentered):              0.762
# Method:                 Least Squares   F-statistic:                              9718.
# Date:                Sun, 19 Oct 2025   Prob (F-statistic):                        0.00
# Time:                        21:59:57   Log-Likelihood:                     -1.0979e+05
# No. Observations:               18180   AIC:                                  2.196e+05
# Df Residuals:                   18174   BIC:                                  2.196e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
from sklearn.metrics import r2_score

# %%
y_pred=model6.predict(X_test)

# %%
def func(t):
    if(t==100):
        return 1
    else:
        return 0
df['best_score_cls']=df['best_score'].apply(func)

# %%
df
# Out:
#        recipe_name                        user_id   user_name  \
# 0         4.452599                 u_9iFLIhMa8QaG     Jeri326
# 1         4.452599                 u_Lu6p25tmE77j     Mark467
# 2         4.452599                 u_s0LwgpZ8Jsqq  Barbara566
# 3         4.452599                 u_fqrybAdYjgjG  jeansch123
# 4         4.452599                 u_XXWKwVhKZD69    camper77
# ...            ...                            ...         ...
# 18175     4.369744  u_1oKblS4ULpTAACUTILo0QlO5mrN  WhittierCA
# 18176     4.369744  u_1oKY7CKLaFQpI3cBCVaxHXAEGbt   susieswan
# 18177     4.369744  u_1oKXBAuHbMDi9nnriVAbJoPqpeQ       blajr
# 18178     4.369744  u_1oKVbnueXfnlmYWuYH8xJ0mFxNQ     cafritz
# 18179     4.369744  u_1oKW6W12cOLxiMzjA7j8nTqwFWG    nopalito
#
#        user_reputation  reply_count  thumbs_up  thumbs_down  stars  \
# 0                    1            0          0            0      5
# 1                   50            0          7            0      5
# ...

# %%
y=df['best_score_cls']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y)

# %%
model=LogisticRegression(max_iter=1000000)

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000000)

# %%
model.score(X_test,y_test)
# Out:
# 0.9938393839383939

# %%
ConfusionMatrixDisplay.from_estimator(model,X_test,y_test)
plt.show()

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# 1    15482
# 0     2698
# Name: count, dtype: int64

# %%
print(classification_report(y_test,model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99      1085
#            1       0.99      1.00      1.00      3460
#
#     accuracy                           0.99      4545
#    macro avg       1.00      0.99      0.99      4545
# weighted avg       0.99      0.99      0.99      4545

# %%
from xgboost import XGBClassifier

# %%
model=XGBClassifier()

# %%
df.columns
# Out:
# Index(['recipe_name', 'user_id', 'user_name', 'user_reputation', 'reply_count',
#        'thumbs_up', 'thumbs_down', 'stars', 'best_score', 'text',
#        'review_vector', 'sentiment', 'best_score_cls'],
#       dtype='object')

# %%
X=df[['review_vector']]

# %%
y=df['sentiment']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y)

# %%
X_train_matrix = np.vstack(X_train['review_vector'].values)
X_test_matrix = np.vstack(X_test['review_vector'].values)

# %%
model.score(X_test_matrix,y_test)
# Out:
# 0.8666666666666667

# %%
ConfusionMatrixDisplay.from_estimator(model,X_test_matrix,y_test)
plt.show()

# %%
from sklearn.utils import class_weight

# %%
weights = class_weight.compute_sample_weight('balanced', y_train)
model.fit(X_train_matrix, y_train, sample_weight=weights)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
model.score(X_test_matrix,y_test)
# Out:
# 0.8521452145214522

# %%
ConfusionMatrixDisplay.from_estimator(model,X_test_matrix,y_test)
plt.show()

# %%
print(classification_report(y_test,model.predict(X_test_matrix)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.41      0.45       659
#            1       0.90      0.93      0.91      3886
#
#     accuracy                           0.85      4545
#    macro avg       0.70      0.67      0.68      4545
# weighted avg       0.84      0.85      0.85      4545

# %%
y_prob=model.predict_proba(X_test_matrix)

# %%
fpr,tpr,thresh=roc_curve(y_test,y_prob[:,1])

# %%
roc_auc_score(y_test,y_prob[:,1])
# Out:
# 0.7546532941487945

# %%
plt.plot(fpr,tpr)
plt.show()

# %%
from collections import Counter

# %%
counter = Counter(y_train)
scale_pos_weight = counter[0] / counter[1]

# %%
model = XGBClassifier(scale_pos_weight=scale_pos_weight)
model.fit(X_train_matrix, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
model.score(X_test_matrix,y_test)
# Out:
# 0.8473047304730473

# %%
ConfusionMatrixDisplay.from_estimator(model,X_test_matrix,y_test)
plt.show()

# %%
print(classification_report(y_test,model.predict(X_test_matrix)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.47      0.44      0.46       659
#            1       0.91      0.92      0.91      3886
#
#     accuracy                           0.85      4545
#    macro avg       0.69      0.68      0.68      4545
# weighted avg       0.84      0.85      0.85      4545

# %%
from sklearn.metrics import roc_curve,roc_auc_score

# %%
y_prob=model.predict_proba(X_test_matrix)

# %%
fpr,tpr,thresh=roc_curve(y_test,y_prob[:,1])

# %%
roc_auc_score(y_test,y_prob[:,1])
# Out:
# 0.7627071851250784

# %%
plt.plot(fpr,tpr)
plt.show()

# %%
X=np.vstack(X['review_vector'].values)

# %%
model.score(X,y)
# Out:
# 0.9554455445544554

# %%
ConfusionMatrixDisplay.from_estimator(model,X,y)
plt.show()

# %%
y_pred=model.predict(X)

# %%
df['predicted']=y_pred

# %%
df.columns
# Out:
# Index(['recipe_name', 'user_id', 'user_name', 'user_reputation', 'reply_count',
#        'thumbs_up', 'thumbs_down', 'stars', 'best_score', 'text',
#        'review_vector', 'sentiment', 'best_score_cls', 'predicted'],
#       dtype='object')

# %%
X=df[['recipe_name','user_reputation','reply_count','thumbs_up','thumbs_down','predicted']]

# %%
y=df['best_score']

# %%
lin_model=sm.OLS(y,X).fit()

# %%
lin_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             best_score   R-squared (uncentered):                   0.762
# Model:                            OLS   Adj. R-squared (uncentered):              0.762
# Method:                 Least Squares   F-statistic:                              9719.
# Date:                Mon, 20 Oct 2025   Prob (F-statistic):                        0.00
# Time:                        10:59:56   Log-Likelihood:                     -1.0979e+05
# No. Observations:               18180   AIC:                                  2.196e+05
# Df Residuals:                   18174   BIC:                                  2.196e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
X=df[['recipe_name','user_reputation','reply_count','thumbs_up','thumbs_down','stars']]

# %%
lin_model2=sm.OLS(y,X).fit()

# %%
lin_model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             best_score   R-squared (uncentered):                   0.762
# Model:                            OLS   Adj. R-squared (uncentered):              0.762
# Method:                 Least Squares   F-statistic:                              9718.
# Date:                Mon, 20 Oct 2025   Prob (F-statistic):                        0.00
# Time:                        11:01:33   Log-Likelihood:                     -1.0979e+05
# No. Observations:               18180   AIC:                                  2.196e+05
# Df Residuals:                   18174   BIC:                                  2.196e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...
